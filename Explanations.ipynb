# %% [markdown]
# <a href="https://colab.research.google.com/github/Tmiller68/machine-learning-fundamentals/blob/main/Explanations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Day 1

# %% [markdown]
# Day 1 was about preparing the data before modeling it. I handled missing values, duplicates, and incorrect data types, separated the features from the target, encoded categorical columns into numbers, and scaled numerical features. I also learned that preprocessing shoulf be fit only to the training data.
#
# *   List item
# *   List item

# %% [markdown]
# Day 2, I trained the logistic regression and a decision tree to classify whether a person earns more than $50k. Logistic regressions combines the features and converts the result into a probablity, while a decision tree makes predicitions through a sequence of feature based questions.

# %% [markdown]
# Day 3, I foucsed on evaluating and intepreting models. I looked at more than accuracy since it can be misleading. I used tools like the confusion matrix, rpecision, recall, and F1-score to understand what types of predicitons the model was getting right or wrong. I also looked at feature importance to see which variables the model relied on most.

# %% [markdown]
# On Day 4, I learned how to combine preprocessing and modeling into one pipeline. I used a ColumnTransformer so numerical columns could be scaled while categorical columns could be one-hot encoded. Then I connected that preprocessing to the classifier in a Pipeline. This prevents data leakage because, during cross-validation, the preprocessing is fit only on the training portion of each fold instead of learning from the validation data. I also compared this with the incorrect method of preprocessing the full dataset before splitting, which can make the model’s score look better than it really is.

# %% [markdown]
# On Day 5, I tuned the random forest model to find better hyperparameter settings. Hyperparameters are settings chosen before training, such as the number of trees, the maximum tree depth, and the minimum number of samples allowed in a leaf. I used RandomizedSearchCV because it tests a selected number of random combinations instead of testing every possible combination like GridSearchCV. The tuning was done inside cross-validation so the test set stayed untouched. After choosing the best model, I evaluated it on the held-out test set only once.
